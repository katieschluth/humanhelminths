# %%
import pandas as pd
import numpy as np
import matplotlib as plt

df = pd.read_csv("helminthreferences.csv")

df.head(51)
#Shows top 50 most referenced helminth species
# Out:
#                           species  references infects_humans
# 0            Ascaris lumbricoides         313              Y
# 1             Trichuris trichiura         244              Y
# 2             Schistosoma mansoni         197              Y
# 3         Echinococcus granulosus         179              Y
# 4         Schistosoma haematobium         159              Y
# 5       Strongyloides stercoralis         158              Y
# 6         Enterobius vermicularis         157              Y
# 7             Onchocerca volvulus         141              Y
# 8                   Taenia solium         139              Y
# 9                Hymenolepis nana         120              Y
# 10           Wuchereria bancrofti         114              Y
# 11                Taenia saginata          92              Y
# 12             Necator americanus          85              Y
# 13    Echinococcus multilocularis          76              Y
# ...

# %%
df.describe()
#Summary of data
# Out:
#        references
# count  409.000000
# mean    12.286064
# std     31.101885
# min      1.000000
# 25%      2.000000
# 50%      3.000000
# 75%      9.000000
# max    313.000000

# %%
df["infects_humans"].value_counts()
#Number of species in dataset who can infect and cannot infect humans
# Out:
# Y    252
# N    157
# Name: infects_humans, dtype: int64

# %%
df.boxplot(column = "references")
#Visual summary of data via boxplot

# %%
 df.apply(lambda x: sum(x.isnull()),axis=0) 
#Check for missing values
# Out:
# species           0
# references        0
# infects_humans    0
# dtype: int64
